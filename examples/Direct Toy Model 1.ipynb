# %%
#Importing and defining functions
import swiglpk
from swiglpk import *
import matplotlib.pyplot as plt

def myfunction(t,y,v):
    return -v * y

def rungekutta(t,y,h,v):
    k1 = h * myfunction(t,y,v)
    k2 = h * myfunction(t + h * 0.5, y + k1 * 0.5,v)
    k3 = h * myfunction(t + h/2, y + k2 * 0.5,v) 
    k4 = h * myfunction(t + h, y + k3,v)
    y = y + (1.0 / 6.0) * (k1 + 2 * k2 + 2 * k3 + k4)
    t = t + h
    return t,y

# %%
#Initial conditions
t = 0
tp = [t]
tmax = 2
y = 1
yp = [y]
h = 0.005
v = 2
#Set up the stoichiometric matrix
ia = intArray(1+1000); ja = intArray(1+1000);
ar = doubleArray(1+1000);
lp = glp_create_prob();
glp_set_prob_name(lp, "sample");
glp_set_obj_dir(lp, GLP_MAX); #Set the objective direction
glp_add_rows(lp, 3);
glp_set_row_name(lp, 1, "p");
glp_set_row_bnds(lp, 1, GLP_UP, 0.0, 100.0);
glp_set_row_name(lp, 2, "q");
glp_set_row_bnds(lp, 2, GLP_UP, 0.0, 600.0);
glp_set_row_name(lp, 3, "r");
glp_set_row_bnds(lp, 3, GLP_UP, 0.0, 300.0);
glp_add_cols(lp, 3);
glp_set_col_name(lp, 1, "x1");
glp_set_col_bnds(lp, 1, GLP_LO, 0.0, 0.0);
glp_set_obj_coef(lp, 1, 10.0);
glp_set_col_name(lp, 2, "x2");
glp_set_col_bnds(lp, 2, GLP_LO, 0.0, 0.0);
glp_set_obj_coef(lp, 2, 6.0);
glp_set_col_name(lp, 3, "x3");
glp_set_col_bnds(lp, 3, GLP_LO, 0.0, 0.0);
glp_set_obj_coef(lp, 3, 4.0);
ia[1] = 1; ja[1] = 1; ar[1] = 1.0; # a[1,1] = 1
ia[2] = 1; ja[2] = 2; ar[2] = 1.0; # a[1,2] = 1
ia[3] = 1; ja[3] = 3; ar[3] = 1.0; # a[1,3] = 1
ia[4] = 2; ja[4] = 1; ar[4] = 10.0; # a[2,1] = 10
ia[5] = 3; ja[5] = 1; ar[5] = 2.0; # a[3,1] = 2
ia[6] = 2; ja[6] = 2; ar[6] = 4.0; # a[2,2] = 4
ia[7] = 3; ja[7] = 2; ar[7] = 2.0; # a[3,2] = 2
ia[8] = 2; ja[8] = 3; ar[8] = 5.0; # a[2,3] = 5
ia[9] = 3; ja[9] = 3; ar[9] = 6.0; # a[3,3] = 6
glp_load_matrix(lp, 9, ia, ja, ar);
glp_simplex(lp, None);
Z = glp_get_obj_val(lp);
Zmax = Z
x1 = glp_get_col_prim(lp, 1);
x2 = glp_get_col_prim(lp, 2);
x3 = glp_get_col_prim(lp, 3);
print("\nZ = %g; x1 = %g; x2 = %g; x3 = %g\n" % (Z, x1, x2, x3))

bl = [0,0,0,0,0,0]
zp = [Z]
x1p = [x1]
x2p = [x2]
x3p = [x3]

#Integrating and resolving the LP
while t < tmax:
    v = Z/Zmax
    t,y = rungekutta(t,y,h,v)
    #THIS IS WHERE WE SET OUR UPDATES TO OUR PROBLEM
    glp_set_row_bnds(lp, 2, GLP_UP, 0.0, 600.0*y);
    #-----------------------------------------------
    glp_load_matrix(lp, 9, ia, ja, ar);
    glp_simplex(lp, None);
    Z = glp_get_obj_val(lp);
    x1 = glp_get_col_prim(lp, 1);
    x2 = glp_get_col_prim(lp, 2);
    x3 = glp_get_col_prim(lp, 3);
    zp = zp + [Z]
    x1p = x1p + [x1]
    x2p = x2p + [x2]
    x3p = x3p + [x3]
    tp = tp + [t]
    yp = yp + [y]
# Out:
# Z = 733.333; x1 = 33.3333; x2 = 66.6667; x3 = 0
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (3)
# *     2: obj =   7.333333333e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
#
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.313383250e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.293586537e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.273941481e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.254446396e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.235099620e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.215899515e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.196844469e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.177932891e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.159163214e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.140533895e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.122043412e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.103690265e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.085472976e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.067390088e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.049440164e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.031621788e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.013933565e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.996374117e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.978942089e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.961636142e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.944454956e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.927397232e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.910461685e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.893647050e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.876952079e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.860375543e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.843916226e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.827572931e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.811344477e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.795229699e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.779227447e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.763336587e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.747556000e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.731884583e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.716321244e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.700864911e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.685514521e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.670269029e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.655127401e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.640088618e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.625151673e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.610315573e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.595579338e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.580942000e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.566402604e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.551960208e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.537613879e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.523362700e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.509205762e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.495142169e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.481171038e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.467291495e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.453502677e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.439803732e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.426193820e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.412672109e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.399237779e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.385890020e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.372628032e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.359451024e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.346358216e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.333348836e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.320422122e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.307577321e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.294813691e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.282130496e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.269527011e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.257002518e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.244556309e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.232187684e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.219895951e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.207680426e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.195540435e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.183475308e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.171484388e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.159567020e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.147722562e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.135950376e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.124249833e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.112620310e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.101061191e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.089571870e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.078151745e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.066800222e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.055516713e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.044300638e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.033151421e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.022068497e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.011051303e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.000099284e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
#       2: obj =   5.989211891e+02 inf =   2.697e-01 (1)
#       3: obj =   5.975726756e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.951429031e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.927328298e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.903422168e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.879708294e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.856184362e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.832848099e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.809697266e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.786729661e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.763943115e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.741335495e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.718904700e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.696648661e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.674565345e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.652652745e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.630908889e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.609331835e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.587919668e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.566670505e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.545582490e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.524653796e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.503882623e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.483267199e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.462805776e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.442496635e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.422338081e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.402328444e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.382466079e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.362749366e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.343176707e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.323746527e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.304457277e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.285307427e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.266295471e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.247419923e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.228679321e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.210072221e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.191597201e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.173252859e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.155037812e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.136950698e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.118990172e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.101154910e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.083443605e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.065854968e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.048387728e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.031040633e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   5.013812446e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.996701949e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.979707938e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.962829228e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.946064648e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.929413044e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.912873277e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.896444224e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.880124776e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.863913840e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.847810335e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.831813198e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.815921377e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.800133834e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.784449547e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.768867505e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.753386712e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.738006182e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.722724944e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.707542040e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.692456523e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.677467458e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.662573923e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.647775007e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.633069811e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.618457446e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.603937037e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.589507716e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.575168631e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.560918935e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.546757796e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.532684389e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.518697903e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.504797533e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.490982487e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.477251981e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.463605240e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.450041500e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.436560006e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.423160012e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.409840781e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.396601583e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.383441700e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.370360421e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.357357043e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.344430871e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.331581221e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.318807414e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.306108781e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.293484659e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.280934394e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.268457339e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.256052857e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.243720314e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.231459087e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.219268559e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.207148119e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.195097164e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.183115099e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.171201334e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.159355287e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.147576381e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.135864048e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.124217723e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.112636850e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.101120880e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.089669267e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.078281473e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.066956966e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.055695220e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.044495713e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.033357933e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.022281368e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.011265516e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.000309879e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.989413963e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.978577283e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.967799355e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.957079704e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.946417857e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.935813348e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.925265716e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.914774504e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.904339260e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.893959537e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.883634894e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.873364893e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.863149100e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.852987089e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.842878434e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.832822717e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.822819523e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.812868441e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.802969065e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.793120992e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.783323826e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.773577171e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.763880638e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.754233841e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.744636399e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.735087933e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.725588070e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.716136439e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.706732673e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.697376410e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.688067290e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.678804958e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.669589063e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.660419254e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.651295189e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.642216524e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.633182921e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.624194047e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.615249569e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.606349160e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.597492493e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.588679248e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.579909105e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.571181750e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.562496869e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.553854154e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.545253297e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.536693995e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.528175948e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.519698858e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.511262431e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.502866373e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.494510397e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.486194215e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.477917544e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.469680103e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.461481613e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.453321800e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.445200388e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.437117109e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.429071694e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.421063878e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.413093397e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.405159990e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.397263401e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.389403372e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.381579651e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.373791986e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.366040128e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.358323832e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.350642853e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.342996948e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.335385879e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.327809407e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.320267297e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.312759315e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.305285231e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.297844816e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.290437842e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.283064083e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.275723319e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.268415326e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.261139886e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.253896783e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.246685800e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.239506725e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.232359346e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.225243453e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.218158840e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.211105300e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.204082628e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.197090624e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.190129086e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.183197815e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.176296615e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.169425289e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.162583646e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.155771492e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.148988637e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.142234892e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.135510071e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.128813988e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.122146459e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.115507302e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.108896335e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.102313381e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.095758260e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.089230798e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.082730818e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.076258148e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.069812617e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.063394052e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.057002287e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.050637152e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.044298483e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.037986114e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.031699881e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.025439624e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.019205180e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.012996391e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.006813098e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.000655146e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.994522377e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.988414639e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.982331778e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.976273642e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.970240081e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.964230945e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.958246087e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.952285359e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.946348617e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.940435715e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.934546510e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.928680859e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.922838623e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.917019660e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.911223832e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.905451001e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.899701031e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.893973786e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.888269131e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.882586933e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.876927060e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.871289380e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.865673763e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.860080080e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.854508202e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.848958003e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.843429355e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.837922133e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.832436214e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.826971473e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.821527788e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.816105038e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.810703103e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.805321862e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.799961196e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.794620989e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.789301123e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.784001481e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.778721950e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.773462414e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.768222760e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.763002876e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.757802650e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.752621971e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.747460728e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.742318814e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.737196119e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.732092535e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.727007957e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.721942277e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.716895392e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.711867195e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.706857585e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.701866457e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.696893710e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.691939242e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.687002953e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.682084742e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.677184512e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.672302162e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.667437596e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.662590716e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.657761426e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.652949631e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.648155236e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.643378145e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   2.638618267e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND

# %%
fig, ax = plt.subplots(figsize=(6, 4), layout='constrained')
linesx1 = ax.plot(tp,x1p,"r",label="v1")
linesx2 = ax.plot(tp,x2p,"g",label="v2")
linesx3 = ax.plot(tp,x3p,"b",label="v3")
plt.legend()
ax.set_xlabel("Time t")
ax.set_ylabel("LP Variables")
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(6, 4), layout='constrained')
linesz = ax.plot(tp,zp,label="Z")
ax.set_xlabel("Time t")
ax.set_ylabel("Objective z")
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(6, 4), layout='constrained')
linesz = ax.plot(tp,yp,"g",label="v")
ax.set_xlabel("Time t")
ax.set_ylabel("Kinetic Variable x")
plt.grid()
