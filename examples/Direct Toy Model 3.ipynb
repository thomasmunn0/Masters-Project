# %%
#Importing and defining functions
import swiglpk
from swiglpk import *
import matplotlib.pyplot as plt

def myfunction(t,y,v):
    return -v * y

def rungekutta(t,y,h,v):
    k1 = h * myfunction(t,y,v)
    k2 = h * myfunction(t + h * 0.5, y + k1 * 0.5,v)
    k3 = h * myfunction(t + h/2, y + k2 * 0.5,v) 
    k4 = h * myfunction(t + h, y + k3,v)
    y = y + (1.0 / 6.0) * (k1 + 2 * k2 + 2 * k3 + k4)
    t = t + h
    return t,y

# %%
#Initial conditions
t = 0
tp = [t]
tmax = 2
y = 1
yp = [y]
h = 0.005
v = 2
#Set up the stoichiometric matrix
ia = intArray(1+1000); ja = intArray(1+1000);
ar = doubleArray(1+1000);
lp = glp_create_prob();
glp_set_prob_name(lp, "sample");
glp_set_obj_dir(lp, GLP_MAX); #Set the objective direction
glp_add_rows(lp, 3);
glp_set_row_name(lp, 1, "p");
glp_set_row_bnds(lp, 1, GLP_UP, 0.0, 100.0);
glp_set_row_name(lp, 2, "q");
glp_set_row_bnds(lp, 2, GLP_UP, 0.0, 600.0);
glp_set_row_name(lp, 3, "r");
glp_set_row_bnds(lp, 3, GLP_UP, 0.0, 300.0);
glp_add_cols(lp, 3);
glp_set_col_name(lp, 1, "x1");
glp_set_col_bnds(lp, 1, GLP_LO, 0.0, 0.0);
glp_set_obj_coef(lp, 1, 10.0);
glp_set_col_name(lp, 2, "x2");
glp_set_col_bnds(lp, 2, GLP_LO, 0.0, 0.0);
glp_set_obj_coef(lp, 2, 7.0);
glp_set_col_name(lp, 3, "x3");
glp_set_col_bnds(lp, 3, GLP_LO, 0.0, 0.0);
glp_set_obj_coef(lp, 3, 0.0);
ia[1] = 1; ja[1] = 1; ar[1] = 1.0; # a[1,1] = 1
ia[2] = 1; ja[2] = 2; ar[2] = 1.0; # a[1,2] = 1
ia[3] = 1; ja[3] = 3; ar[3] = 1.0; # a[1,3] = 1
ia[4] = 2; ja[4] = 1; ar[4] = 10.0; # a[2,1] = 10
ia[5] = 3; ja[5] = 1; ar[5] = 2.0; # a[3,1] = 2
ia[6] = 2; ja[6] = 2; ar[6] = 4.0; # a[2,2] = 4
ia[7] = 3; ja[7] = 2; ar[7] = 2.0; # a[3,2] = 2
ia[8] = 2; ja[8] = 3; ar[8] = 5.0; # a[2,3] = 5
ia[9] = 3; ja[9] = 3; ar[9] = 6.0; # a[3,3] = 6
glp_load_matrix(lp, 9, ia, ja, ar);
glp_simplex(lp, None);
Z = glp_get_obj_val(lp);
Zmax = Z
x1 = glp_get_col_prim(lp, 1);
x2 = glp_get_col_prim(lp, 2);
x3 = glp_get_col_prim(lp, 3);
print("\nZ = %g; x1 = %g; x2 = %g; x3 = %g\n" % (Z, x1, x2, x3))

bl = [0,0,0,0,0,0]
zp = [Z]
x1p = [x1]
x2p = [x2]
x3p = [x3]

#Integrating and resolving the LP
while t < tmax:
    v = Z/Zmax
    t,y = rungekutta(t,y,h,v)
    #THIS IS WHERE WE SET OUR UPDATES TO OUR PROBLEM
    glp_set_row_bnds(lp, 2, GLP_UP, 0.0, 600.0*y);
    glp_set_obj_coef(lp,2,7.0*y);
    glp_set_obj_coef(lp,3,15.0*(1-y));
    #-----------------------------------------------
    glp_load_matrix(lp, 9, ia, ja, ar);
    glp_simplex(lp, None);
    Z = glp_get_obj_val(lp);
    x1 = glp_get_col_prim(lp, 1);
    x2 = glp_get_col_prim(lp, 2);
    x3 = glp_get_col_prim(lp, 3);
    zp = zp + [Z]
    x1p = x1p + [x1]
    x2p = x2p + [x2]
    x3p = x3p + [x3]
    tp = tp + [t]
    yp = yp + [y]
# Out:
# Z = 800; x1 = 33.3333; x2 = 66.6667; x3 = 0
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (2)
# *     2: obj =   8.000000000e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
#
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.961588213e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.923207886e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.884865193e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.846566092e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.808316334e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.770121463e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.731986824e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.693917569e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.655918659e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.617994871e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.580150803e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.542390878e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.504719347e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.467140298e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.429657656e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.392275190e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.354996515e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.317825100e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.280764268e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.243817203e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.206986952e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.170276430e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.133688424e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.097225596e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.060890486e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.024685519e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.988613003e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.952675137e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.916874011e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.881211613e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.845689829e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.810310446e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.775075158e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.739985566e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.705043181e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.670249429e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.635605653e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.601113111e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.566772988e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.532586390e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.498554348e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.464677826e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.430957715e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.397394843e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.363989971e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.330743798e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.297656966e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.264730054e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.231963588e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.199358038e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.166913824e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.134631313e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.102510824e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.070552628e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.038756952e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.007123977e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.975653844e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.944346651e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.913202459e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.882221288e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.851403123e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.820747915e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.790255579e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.759925998e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.729759024e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.699754478e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.669912153e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.640231814e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.610713197e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.581356015e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.552159954e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.523124678e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.494249827e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.465535019e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.436979852e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.408583902e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.380346729e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.352267871e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.324346850e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.296583171e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.268976324e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.241525781e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.214231002e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.187091430e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.160106498e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.133275623e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.106598213e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.080073662e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.053701354e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.027480663e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.001410952e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   4.975491576e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   4.949721881e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   4.924101203e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   4.898628872e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   4.873304209e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   4.848126531e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   4.823095145e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   4.798209353e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   4.773468452e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   4.748871734e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   4.724418484e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   4.700107985e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   4.675939512e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
#       2: obj =   4.651912341e+02 inf =   1.195e-01 (1)
#       3: obj =   4.649944876e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.622995788e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.596357717e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.570025304e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.543993315e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.518256633e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.492810255e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.467649293e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.442768968e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.418164606e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.393831636e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.369765590e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.345962095e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.322416874e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.299125742e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.276084605e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.253289457e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.230736374e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.208421518e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.186341132e+02 inf =   0.000e+00 (1)
# *     4: obj =   4.187486562e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   4.178074672e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   4.168875331e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   4.159885429e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   4.151101934e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   4.142521883e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   4.134142384e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   4.125960613e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   4.117973810e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   4.110179282e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   4.102574398e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   4.095156586e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   4.087923335e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   4.080872191e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   4.074000756e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   4.067306686e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   4.060787693e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   4.054441537e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   4.048266030e+02 inf =   0.000e+00 (1)
# *     5: obj =   4.052950757e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.054574986e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.056212449e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.057863049e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.059526692e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.061203282e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.062892726e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.064594930e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.066309802e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.068037248e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.069777177e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.071529497e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.073294117e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.075070947e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.076859898e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.078660880e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.080473803e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.082298580e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.084135123e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.085983344e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.087843157e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.089714474e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.091597211e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.093491282e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.095396601e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.097313084e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.099240647e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.101179206e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.103128679e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.105088981e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.107060032e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.109041749e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.111034050e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.113036855e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.115050083e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.117073653e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.119107486e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.121151502e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.123205623e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.125269770e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.127343864e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.129427828e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.131521584e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.133625055e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.135738165e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.137860837e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.139992996e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.142134565e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.144285470e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.146445635e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.148614987e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.150793452e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.152980954e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.155177422e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.157382782e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.159596961e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.161819887e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.164051488e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.166291692e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.168540428e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.170797625e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.173063213e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.175337120e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.177619276e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.179909613e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.182208060e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.184514549e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.186829011e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.189151377e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.191481578e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.193819548e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.196165219e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.198518523e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.200879394e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.203247764e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.205623568e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.208006738e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.210397211e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.212794919e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.215199798e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.217611783e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.220030809e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.222456812e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.224889727e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.227329491e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.229776040e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.232229312e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.234689242e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.237155768e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.239628828e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.242108359e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.244594300e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.247086589e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.249585164e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.252089964e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.254600928e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.257117995e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.259641106e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.262170199e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.264705215e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.267246095e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.269792778e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.272345205e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.274903319e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.277467059e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.280036367e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.282611186e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.285191456e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.287777121e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.290368123e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.292964404e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.295565908e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.298172577e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.300784355e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.303401185e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.306023012e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.308649779e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.311281431e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.313917912e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.316559167e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.319205141e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.321855779e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.324511027e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.327170829e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.329835132e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.332503882e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.335177025e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.337854508e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.340536277e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.343222279e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.345912461e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.348606770e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.351305155e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.354007562e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.356713940e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.359424236e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.362138400e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.364856379e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.367578123e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.370303579e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     5: obj =   4.373032699e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
#       5: obj =   4.375765430e+02 inf =   2.295e-02 (1)
#       6: obj =   4.374041841e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.370595599e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.367115203e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.363601121e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.360053816e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.356473749e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.352861375e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.349217149e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.345541522e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.341834939e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.338097844e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.334330678e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.330533878e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.326707875e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.322853102e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.318969983e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.315058943e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.311120401e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.307154773e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.303162474e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.299143911e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.295099493e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.291029621e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.286934695e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.282815111e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.278671263e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.274503540e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.270312327e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.266098008e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.261860962e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.257601565e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.253320190e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.249017207e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.244692981e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.240347876e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.235982251e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.231596462e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.227190863e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.222765803e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.218321629e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.213858685e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.209377309e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.204877840e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.200360611e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.195825953e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.191274192e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.186705654e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.182120658e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.177519525e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.172902567e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.168270097e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.163622424e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.158959852e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.154282686e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.149591224e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.144885763e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.140166597e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.135434016e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.130688307e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.125929756e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.121158643e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.116375249e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.111579848e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.106772714e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.101954118e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.097124325e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.092283602e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.087432209e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.082570406e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.077698448e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.072816590e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.067925081e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.063024170e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.058114102e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.053195120e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.048267463e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.043331369e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.038387073e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.033434806e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.028474798e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.023507276e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.018532464e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.013550584e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.008561856e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   4.003566497e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.998564720e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.993556737e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.988542759e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.983522992e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.978497641e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.973466909e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.968430994e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.963390096e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.958344409e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.953294126e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.948239438e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.943180533e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.938117598e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.933050817e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.927980371e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.922906441e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.917829203e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.912748833e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.907665504e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.902579388e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.897490653e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.892399465e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.887305991e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.882210393e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.877112831e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.872013464e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.866912450e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.861809943e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.856706096e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.851601059e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.846494983e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.841388014e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.836280297e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     6: obj =   3.831171977e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND

# %%
fig, ax = plt.subplots(figsize=(6, 4), layout='constrained')
linesx1 = ax.plot(tp,x1p,"r",label="v1")
linesx2 = ax.plot(tp,x2p,"g",label="v2")
linesx3 = ax.plot(tp,x3p,"b",label="v3")
plt.legend()
ax.set_xlabel("Time t")
ax.set_ylabel("LP Variables")
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(6, 4), layout='constrained')
linesz = ax.plot(tp,zp,label="Z")
ax.set_xlabel("Time t")
ax.set_ylabel("Objective z")
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(6, 4), layout='constrained')
linesz = ax.plot(tp,yp,"g",label="v")
ax.set_xlabel("Time t")
ax.set_ylabel("Kinetic Variable x")
plt.grid()
