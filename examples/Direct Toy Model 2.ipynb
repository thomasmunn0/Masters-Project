# %%
#Importing and defining functions
import swiglpk
from swiglpk import *
import matplotlib.pyplot as plt

def myfunction(t,y,v):
    return -v * y

def rungekutta(t,y,h,v):
    k1 = h * myfunction(t,y,v)
    k2 = h * myfunction(t + h * 0.5, y + k1 * 0.5,v)
    k3 = h * myfunction(t + h/2, y + k2 * 0.5,v) 
    k4 = h * myfunction(t + h, y + k3,v)
    y = y + (1.0 / 6.0) * (k1 + 2 * k2 + 2 * k3 + k4)
    t = t + h
    return t,y

# %%
#Initial conditions
t = 0
tp = [t]
tmax = 2
y = 1
yp = [y]
h = 0.005
v = 2
#Set up the stoichiometric matrix
ia = intArray(1+1000); ja = intArray(1+1000);
ar = doubleArray(1+1000);
lp = glp_create_prob();
glp_set_prob_name(lp, "sample");
glp_set_obj_dir(lp, GLP_MAX); #Set the objective direction
glp_add_rows(lp, 3);
glp_set_row_name(lp, 1, "p");
glp_set_row_bnds(lp, 1, GLP_UP, 0.0, 100.0);
glp_set_row_name(lp, 2, "q");
glp_set_row_bnds(lp, 2, GLP_UP, 0.0, 600.0);
glp_set_row_name(lp, 3, "r");
glp_set_row_bnds(lp, 3, GLP_UP, 0.0, 300.0);
glp_add_cols(lp, 3);
glp_set_col_name(lp, 1, "x1");
glp_set_col_bnds(lp, 1, GLP_LO, 0.0, 0.0);
glp_set_obj_coef(lp, 1, 10.0);
glp_set_col_name(lp, 2, "x2");
glp_set_col_bnds(lp, 2, GLP_LO, 0.0, 0.0);
glp_set_obj_coef(lp, 2, 7.0);
glp_set_col_name(lp, 3, "x3");
glp_set_col_bnds(lp, 3, GLP_LO, 0.0, 0.0);
glp_set_obj_coef(lp, 3, 4.0);
ia[1] = 1; ja[1] = 1; ar[1] = 1.0; # a[1,1] = 1
ia[2] = 1; ja[2] = 2; ar[2] = 1.0; # a[1,2] = 1
ia[3] = 1; ja[3] = 3; ar[3] = 1.0; # a[1,3] = 1
ia[4] = 2; ja[4] = 1; ar[4] = 10.0; # a[2,1] = 10
ia[5] = 3; ja[5] = 1; ar[5] = 2.0; # a[3,1] = 2
ia[6] = 2; ja[6] = 2; ar[6] = 4.0; # a[2,2] = 4
ia[7] = 3; ja[7] = 2; ar[7] = 2.0; # a[3,2] = 2
ia[8] = 2; ja[8] = 3; ar[8] = 5.0; # a[2,3] = 5
ia[9] = 3; ja[9] = 3; ar[9] = 6.0; # a[3,3] = 6
glp_load_matrix(lp, 9, ia, ja, ar);
glp_simplex(lp, None);
Z = glp_get_obj_val(lp);
Zmax = Z
x1 = glp_get_col_prim(lp, 1);
x2 = glp_get_col_prim(lp, 2);
x3 = glp_get_col_prim(lp, 3);
print("\nZ = %g; x1 = %g; x2 = %g; x3 = %g\n" % (Z, x1, x2, x3))

bl = [0,0,0,0,0,0]
zp = [Z]
x1p = [x1]
x2p = [x2]
x3p = [x3]

#Integrating and resolving the LP
while t < tmax:
    v = Z/Zmax
    t,y = rungekutta(t,y,h,v)
    #THIS IS WHERE WE SET OUR UPDATES TO OUR PROBLEM
    glp_set_row_bnds(lp, 2, GLP_UP, 0.0, 600.0*y);
    glp_set_obj_coef(lp,2,7.0*y);
    #-----------------------------------------------
    glp_load_matrix(lp, 9, ia, ja, ar);
    glp_simplex(lp, None);
    Z = glp_get_obj_val(lp);
    x1 = glp_get_col_prim(lp, 1);
    x2 = glp_get_col_prim(lp, 2);
    x3 = glp_get_col_prim(lp, 3);
    zp = zp + [Z]
    x1p = x1p + [x1]
    x2p = x2p + [x2]
    x3p = x3p + [x3]
    tp = tp + [t]
    yp = yp + [y]
# Out:
# Z = 800; x1 = 33.3333; x2 = 66.6667; x3 = 0
#
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (3)
# *     2: obj =   8.000000000e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.961588213e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.923207886e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.884865193e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.846566092e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.808316334e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.770121463e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.731986824e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.693917569e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.655918659e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.617994871e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.580150803e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.542390878e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.504719347e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.467140298e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.429657656e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.392275190e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.354996515e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.317825100e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.280764268e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.243817203e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.206986952e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.170276430e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.133688424e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.097225596e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.060890486e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   7.024685519e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.988613003e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.952675137e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.916874011e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.881211613e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.845689829e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.810310446e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.775075158e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.739985566e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.705043181e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.670249429e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.635605653e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.601113111e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.566772988e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.532586390e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.498554348e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.464677826e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.430957715e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.397394843e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.363989971e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.330743798e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.297656966e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.264730054e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.231963588e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.199358038e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.166913824e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.134631313e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.102510824e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.070552628e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.038756952e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   6.007123977e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.975653844e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.944346651e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.913202459e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.882221288e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.851403123e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.820747915e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.790255579e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.759925998e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.729759024e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.699754478e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.669912153e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.640231814e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.610713197e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.581356015e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.552159954e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.523124678e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.494249827e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.465535019e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.436979852e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.408583902e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.380346729e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.352267871e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.324346850e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.296583171e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.268976324e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.241525781e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.214231002e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.187091430e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.160106498e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.133275623e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.106598213e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.080073662e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.053701354e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.027480663e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   5.001410952e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   4.975491576e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   4.949721881e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   4.924101203e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   4.898628872e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   4.873304209e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   4.848126531e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   4.823095145e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   4.798209353e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   4.773468452e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   4.748871734e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   4.724418484e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   4.700107985e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     2: obj =   4.675939512e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
#       2: obj =   4.651912341e+02 inf =   1.195e-01 (1)
#       3: obj =   4.649944876e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.622995788e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.596357717e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.570025304e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.543993315e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.518256633e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.492810255e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.467649293e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.442768968e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.418164606e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.393831636e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.369765590e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.345962095e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.322416874e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.299125742e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.276084605e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.253289457e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.230736374e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.208421518e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.186341132e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.164491535e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.142869126e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.121470375e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.100291829e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.079330102e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.058581878e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.038043911e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   4.017713016e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.997586076e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.977660035e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.957931896e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.938398724e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.919057641e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.899905824e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.880940506e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.862158975e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.843558570e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.825136681e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.806890748e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.788818261e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.770916755e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.753183815e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.735617068e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.718214188e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.700972890e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.683890932e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.666966115e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.650196278e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.633579300e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.617113100e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.600795632e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.584624890e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.568598902e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.552715731e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.536973476e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.521370267e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.505904270e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.490573681e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.475376728e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.460311670e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.445376797e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.430570427e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     3: obj =   3.415890907e+02 inf =   0.000e+00 (1)
# *     4: obj =   3.422225294e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.414913351e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.407632602e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.400382850e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.393163897e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.385975546e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.378817604e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.371689877e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.364592175e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.357524309e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.350486090e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.343477333e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.336497853e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.329547466e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.322625991e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.315733248e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.308869059e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.302033246e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.295225633e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.288446047e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.281694314e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.274970264e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.268273726e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.261604531e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.254962513e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.248347506e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.241759345e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.235197867e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.228662910e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.222154314e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.215671920e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.209215569e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.202785105e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.196380372e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.190001216e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.183647485e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.177319026e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.171015689e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.164737325e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.158483785e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.152254923e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.146050592e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.139870648e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.133714948e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.127583349e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.121475709e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.115391889e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.109331749e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.103295152e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.097281959e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.091292037e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.085325249e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.079381461e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.073460542e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.067562359e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.061686781e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.055833680e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.050002925e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.044194389e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.038407946e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.032643469e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.026900834e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.021179917e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.015480595e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.009802745e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   3.004146246e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.998510979e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.992896824e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.987303662e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.981731376e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.976179849e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.970648966e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.965138611e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.959648670e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.954179030e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.948729579e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.943300205e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.937890797e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.932501245e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.927131440e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.921781274e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.916450639e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.911139428e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.905847536e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.900574857e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.895321286e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.890086720e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.884871057e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.879674192e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.874496027e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.869336458e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.864195387e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.859072714e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.853968340e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.848882168e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.843814101e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.838764041e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.833731893e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.828717562e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.823720953e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.818741973e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.813780528e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.808836526e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.803909875e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.799000484e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.794108262e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.789233119e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.784374967e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.779533716e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.774709277e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.769901565e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.765110492e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.760335971e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.755577917e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.750836246e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.746110871e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.741401711e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.736708680e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.732031697e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.727370680e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.722725546e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.718096214e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.713482605e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.708884637e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.704302232e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.699735311e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.695183796e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.690647608e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.686126670e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.681620905e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.677130238e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.672654592e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.668193892e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.663748063e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.659317031e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.654900723e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.650499065e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.646111984e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.641739408e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.637381264e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.633037483e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.628707992e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.624392722e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.620091602e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.615804563e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.611531536e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.607272453e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.603027244e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.598795843e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.594578181e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.590374193e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.586183812e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.582006972e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.577843608e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.573693653e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.569557044e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.565433716e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.561323606e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.557226649e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.553142784e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.549071946e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.545014075e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.540969107e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.536936982e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.532917639e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.528911016e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.524917054e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.520935692e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.516966872e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.513010533e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.509066617e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.505135066e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.501215822e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.497308826e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.493414022e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.489531352e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.485660760e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.481802190e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.477955585e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.474120890e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.470298050e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.466487010e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.462687715e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.458900112e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.455124146e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.451359763e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.447606910e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.443865536e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.440135586e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.436417008e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.432709752e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.429013764e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.425328995e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.421655392e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.417992905e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.414341484e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.410701078e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.407071638e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.403453114e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.399845458e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.396248620e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.392662551e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.389087204e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.385522530e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.381968481e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.378425011e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.374892071e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.371369616e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.367857598e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.364355971e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.360864690e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.357383707e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.353912978e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.350452458e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.347002101e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.343561863e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.340131700e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.336711566e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.333301419e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.329901214e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.326510908e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.323130458e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.319759822e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.316398955e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.313047816e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.309706363e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.306374554e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.303052347e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.299739700e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.296436573e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.293142924e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.289858713e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.286583899e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.283318441e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# GLPK Simplex Optimizer 5.0
# 3 rows, 3 columns, 9 non-zeros
# *     4: obj =   2.280062301e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND

# %%
fig, ax = plt.subplots(figsize=(6, 4), layout='constrained')
linesx1 = ax.plot(tp,x1p,"r",label="v1")
linesx2 = ax.plot(tp,x2p,"g",label="v2")
linesx3 = ax.plot(tp,x3p,"b",label="v3")
plt.legend()
ax.set_xlabel("Time t")
ax.set_ylabel("LP Variables")
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(6, 4), layout='constrained')
linesz = ax.plot(tp,zp,label="Z")
ax.set_xlabel("Time t")
ax.set_ylabel("Objective z")
plt.grid()

# %%
fig, ax = plt.subplots(figsize=(6, 4), layout='constrained')
linesz = ax.plot(tp,yp,"g",label="v")
ax.set_xlabel("Time t")
ax.set_ylabel("Kinetic Variable x")
plt.grid()
